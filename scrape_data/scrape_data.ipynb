# %%
from selenium import webdriver
from pathlib import Path
from selenium.webdriver.common.keys import Keys

# %%
path = str(Path().absolute()) + '/chromedriver'

options = webdriver.ChromeOptions()
options.add_argument('--ignore-certificate-errors')
options.add_argument('--incognito')
options.add_argument('--headless')
driver = webdriver.Chrome(path, options=options)

# %%
# obtain each pokemon's href in order to extract each pokemon's info
url = "https://pokemon.gameinfo.io/"

driver.get(url)

href_objs = []

for i in range(9):
    href_objs = href_objs + driver.find_elements_by_xpath('//a[@class="pokemon g' + str(i) + '"]') 
    
len(href_objs)
# Out:
# 652

# %%
# obtain hrefs from each href object
hrefs = [(link.get_attribute("href"), link.get_attribute("data-name"), 
                      link.get_attribute("data-gen")) for link in href_objs]

assert len(hrefs) == len(href_objs)

# %%
# scrape pokemon info from each href
def parse_href_object(href, name, gen):
    indiv_data = {}

    indiv_data['ID'] = href.split('/')[-1].split('-')[0]
    indiv_data['Name'] = name
    indiv_data['Generation'] = gen
    
    print(href, name, gen, indiv_data['ID'])
    
    driver.get(href)
    
    types = driver.find_elements_by_css_selector('div.type.large')
    
    indiv_data['Type 1'] = types[0].text 
    indiv_data['Type 2'] = None if len(types) < 2 else types[1].text 
    
    tables = driver.find_element_by_id('stats').find_elements_by_class_name("table-stats")
    headers = driver.find_element_by_id('stats').find_elements_by_tag_name("h3")
    headers = ['Stats'] + [header.text for header in headers]
    stats = tables[headers.index('Stats')].text.split()
    
    indiv_data['Attack'] = int(stats[1])
    indiv_data['Defense'] = int(stats[3])
    indiv_data['Stamina'] = int(stats[-1])
    indiv_data['Max CP'] = int("".join(tables[headers.index('Max CP')].text.split('\n')[-1].split()[2].split(',')))
    indiv_data['Max HP'] = int(tables[headers.index('Max HP')].text.split()[-1])
    
    size = tables[headers.index('Size')].text.split()  
    other = tables[headers.index('Other')].text.split() 
    
    indiv_data['Height (m)'] = float(size[1])
    indiv_data['Weight (kg)'] = float(size[-2])
    indiv_data['Base Capture Rate (%)'] = float(other[3].split('%')[0])
    indiv_data['Base Flee Rate (%)'] = float(other[7].split('%')[0])
    indiv_data['Distance to Candy (km)'] = int(other[-2])
    
    img = driver.find_elements_by_css_selector("a.game-image")
    indiv_data['Image URL'] = None if len(img) < 1 else img[0].get_attribute("href")
    
    sum_abt = driver.find_elements_by_class_name("description")
    
    indiv_data['Summary'] = None if len(sum_abt) < 1 else sum_abt[0].text
    indiv_data['About'] = None if len(sum_abt) < 2 else sum_abt[1].text.replace('"', "")
    indiv_data['Is Legendary'] = None if not indiv_data['Summary'] else "legendary" in indiv_data['Summary'].lower()
    
    return indiv_data

# %%
pokemon_data = [parse_href_object(href, name, gen) for href,name,gen in hrefs]
# Out:
# https://pokemon.gameinfo.io/en/pokemon/1-bulbasaur bulbasaur 1 1
# https://pokemon.gameinfo.io/en/pokemon/2-ivysaur ivysaur 1 2
# https://pokemon.gameinfo.io/en/pokemon/3-venusaur venusaur 1 3
# https://pokemon.gameinfo.io/en/pokemon/4-charmander charmander 1 4
# https://pokemon.gameinfo.io/en/pokemon/5-charmeleon charmeleon 1 5
# https://pokemon.gameinfo.io/en/pokemon/6-charizard charizard 1 6
# https://pokemon.gameinfo.io/en/pokemon/7-squirtle squirtle 1 7
# https://pokemon.gameinfo.io/en/pokemon/8-wartortle wartortle 1 8
# https://pokemon.gameinfo.io/en/pokemon/9-blastoise blastoise 1 9
# https://pokemon.gameinfo.io/en/pokemon/10-caterpie caterpie 1 10
# https://pokemon.gameinfo.io/en/pokemon/11-metapod metapod 1 11
# https://pokemon.gameinfo.io/en/pokemon/12-butterfree butterfree 1 12
# https://pokemon.gameinfo.io/en/pokemon/13-weedle weedle 1 13
# https://pokemon.gameinfo.io/en/pokemon/14-kakuna kakuna 1 14
# https://pokemon.gameinfo.io/en/pokemon/15-beedrill beedrill 1 15
# https://pokemon.gameinfo.io/en/pokemon/16-pidgey pidgey 1 16
# https://pokemon.gameinfo.io/en/pokemon/17-pidgeotto pidgeotto 1 17
# https://pokemon.gameinfo.io/en/pokemon/18-pidgeot pidgeot 1 18
# https://pokemon.gameinfo.io/en/pokemon/19-rattata rattata 1 19
# https://pokemon.gameinfo.io/en/pokemon/20-raticate raticate 1 20
# https://pokemon.gameinfo.io/en/pokemon/21-spearow spearow 1 21
# https://pokemon.gameinfo.io/en/pokemon/22-fearow fearow 1 22
# https://pokemon.gameinfo.io/en/pokemon/23-ekans ekans 1 23
# https://pokemon.gameinfo.io/en/pokemon/24-arbok arbok 1 24
# https://pokemon.gameinfo.io/en/pokemon/25-pikachu pikachu 1 25
# https://pokemon.gameinfo.io/en/pokemon/26-raichu raichu 1 26
# https://pokemon.gameinfo.io/en/pokemon/27-sandshrew sandshrew 1 27
# https://pokemon.gameinfo.io/en/pokemon/28-sandslash sandslash 1 28
# https://pokemon.gameinfo.io/en/pokemon/29-nidoran nidoran♀ 1 29
# https://pokemon.gameinfo.io/en/pokemon/30-nidorina nidorina 1 30
# https://pokemon.gameinfo.io/en/pokemon/31-nidoqueen nidoqueen 1 31
# https://pokemon.gameinfo.io/en/pokemon/32-nidoran nidoran♂ 1 32
# https://pokemon.gameinfo.io/en/pokemon/33-nidorino nidorino 1 33
# https://pokemon.gameinfo.io/en/pokemon/34-nidoking nidoking 1 34
# https://pokemon.gameinfo.io/en/pokemon/35-clefairy clefairy 1 35
# https://pokemon.gameinfo.io/en/pokemon/36-clefable clefable 1 36
# https://pokemon.gameinfo.io/en/pokemon/37-vulpix vulpix 1 37
# https://pokemon.gameinfo.io/en/pokemon/38-ninetales ninetales 1 38
# https://pokemon.gameinfo.io/en/pokemon/39-jigglypuff jigglypuff 1 39
# https://pokemon.gameinfo.io/en/pokemon/40-wigglytuff wigglytuff 1 40
# https://pokemon.gameinfo.io/en/pokemon/41-zubat zubat 1 41
# https://pokemon.gameinfo.io/en/pokemon/42-golbat golbat 1 42
# https://pokemon.gameinfo.io/en/pokemon/43-oddish oddish 1 43
# https://pokemon.gameinfo.io/en/pokemon/44-gloom gloom 1 44
# https://pokemon.gameinfo.io/en/pokemon/45-vileplume vileplume 1 45
# https://pokemon.gameinfo.io/en/pokemon/46-paras paras 1 46
# https://pokemon.gameinfo.io/en/pokemon/47-parasect parasect 1 47
# https://pokemon.gameinfo.io/en/pokemon/48-venonat venonat 1 48
# https://pokemon.gameinfo.io/en/pokemon/49-venomoth venomoth 1 49
# https://pokemon.gameinfo.io/en/pokemon/50-diglett diglett 1 50
# https://pokemon.gameinfo.io/en/pokemon/51-dugtrio dugtrio 1 51
# https://pokemon.gameinfo.io/en/pokemon/52-meowth meowth 1 52
# https://pokemon.gameinfo.io/en/pokemon/53-persian persian 1 53
# https://pokemon.gameinfo.io/en/pokemon/54-psyduck psyduck 1 54
# https://pokemon.gameinfo.io/en/pokemon/55-golduck golduck 1 55
# https://pokemon.gameinfo.io/en/pokemon/56-mankey mankey 1 56
# https://pokemon.gameinfo.io/en/pokemon/57-primeape primeape 1 57
# https://pokemon.gameinfo.io/en/pokemon/58-growlithe growlithe 1 58
# https://pokemon.gameinfo.io/en/pokemon/59-arcanine arcanine 1 59
# https://pokemon.gameinfo.io/en/pokemon/60-poliwag poliwag 1 60
# https://pokemon.gameinfo.io/en/pokemon/61-poliwhirl poliwhirl 1 61
# https://pokemon.gameinfo.io/en/pokemon/62-poliwrath poliwrath 1 62
# https://pokemon.gameinfo.io/en/pokemon/63-abra abra 1 63
# https://pokemon.gameinfo.io/en/pokemon/64-kadabra kadabra 1 64
# https://pokemon.gameinfo.io/en/pokemon/65-alakazam alakazam 1 65
# https://pokemon.gameinfo.io/en/pokemon/66-machop machop 1 66
# https://pokemon.gameinfo.io/en/pokemon/67-machoke machoke 1 67
# https://pokemon.gameinfo.io/en/pokemon/68-machamp machamp 1 68
# https://pokemon.gameinfo.io/en/pokemon/69-bellsprout bellsprout 1 69
# https://pokemon.gameinfo.io/en/pokemon/70-weepinbell weepinbell 1 70
# https://pokemon.gameinfo.io/en/pokemon/71-victreebel victreebel 1 71
# https://pokemon.gameinfo.io/en/pokemon/72-tentacool tentacool 1 72
# https://pokemon.gameinfo.io/en/pokemon/73-tentacruel tentacruel 1 73
# https://pokemon.gameinfo.io/en/pokemon/74-geodude geodude 1 74
# https://pokemon.gameinfo.io/en/pokemon/75-graveler graveler 1 75
# https://pokemon.gameinfo.io/en/pokemon/76-golem golem 1 76
# https://pokemon.gameinfo.io/en/pokemon/77-ponyta ponyta 1 77
# https://pokemon.gameinfo.io/en/pokemon/78-rapidash rapidash 1 78
# https://pokemon.gameinfo.io/en/pokemon/79-slowpoke slowpoke 1 79
# https://pokemon.gameinfo.io/en/pokemon/80-slowbro slowbro 1 80
# https://pokemon.gameinfo.io/en/pokemon/81-magnemite magnemite 1 81
# https://pokemon.gameinfo.io/en/pokemon/82-magneton magneton 1 82
# https://pokemon.gameinfo.io/en/pokemon/83-farfetchd farfetch'd 1 83
# https://pokemon.gameinfo.io/en/pokemon/84-doduo doduo 1 84
# https://pokemon.gameinfo.io/en/pokemon/85-dodrio dodrio 1 85
# https://pokemon.gameinfo.io/en/pokemon/86-seel seel 1 86
# https://pokemon.gameinfo.io/en/pokemon/87-dewgong dewgong 1 87
# https://pokemon.gameinfo.io/en/pokemon/88-grimer grimer 1 88
# https://pokemon.gameinfo.io/en/pokemon/89-muk muk 1 89
# https://pokemon.gameinfo.io/en/pokemon/90-shellder shellder 1 90
# https://pokemon.gameinfo.io/en/pokemon/91-cloyster cloyster 1 91
# https://pokemon.gameinfo.io/en/pokemon/92-gastly gastly 1 92
# https://pokemon.gameinfo.io/en/pokemon/93-haunter haunter 1 93
# https://pokemon.gameinfo.io/en/pokemon/94-gengar gengar 1 94
# https://pokemon.gameinfo.io/en/pokemon/95-onix onix 1 95
# https://pokemon.gameinfo.io/en/pokemon/96-drowzee drowzee 1 96
# https://pokemon.gameinfo.io/en/pokemon/97-hypno hypno 1 97
# https://pokemon.gameinfo.io/en/pokemon/98-krabby krabby 1 98
# https://pokemon.gameinfo.io/en/pokemon/99-kingler kingler 1 99
# https://pokemon.gameinfo.io/en/pokemon/100-voltorb voltorb 1 100
# https://pokemon.gameinfo.io/en/pokemon/101-electrode electrode 1 101
# https://pokemon.gameinfo.io/en/pokemon/102-exeggcute exeggcute 1 102
# https://pokemon.gameinfo.io/en/pokemon/103-exeggutor exeggutor 1 103
# https://pokemon.gameinfo.io/en/pokemon/104-cubone cubone 1 104
# https://pokemon.gameinfo.io/en/pokemon/105-marowak marowak 1 105
# https://pokemon.gameinfo.io/en/pokemon/106-hitmonlee hitmonlee 1 106
# https://pokemon.gameinfo.io/en/pokemon/107-hitmonchan hitmonchan 1 107
# https://pokemon.gameinfo.io/en/pokemon/108-lickitung lickitung 1 108
# https://pokemon.gameinfo.io/en/pokemon/109-koffing koffing 1 109
# https://pokemon.gameinfo.io/en/pokemon/110-weezing weezing 1 110
# https://pokemon.gameinfo.io/en/pokemon/111-rhyhorn rhyhorn 1 111
# https://pokemon.gameinfo.io/en/pokemon/112-rhydon rhydon 1 112
# https://pokemon.gameinfo.io/en/pokemon/113-chansey chansey 1 113
# https://pokemon.gameinfo.io/en/pokemon/114-tangela tangela 1 114
# https://pokemon.gameinfo.io/en/pokemon/115-kangaskhan kangaskhan 1 115
# https://pokemon.gameinfo.io/en/pokemon/116-horsea horsea 1 116
# https://pokemon.gameinfo.io/en/pokemon/117-seadra seadra 1 117
# https://pokemon.gameinfo.io/en/pokemon/118-goldeen goldeen 1 118
# https://pokemon.gameinfo.io/en/pokemon/119-seaking seaking 1 119
# https://pokemon.gameinfo.io/en/pokemon/120-staryu staryu 1 120
# https://pokemon.gameinfo.io/en/pokemon/121-starmie starmie 1 121
# https://pokemon.gameinfo.io/en/pokemon/122-mr-mime mr. mime 1 122
# https://pokemon.gameinfo.io/en/pokemon/123-scyther scyther 1 123
# https://pokemon.gameinfo.io/en/pokemon/124-jynx jynx 1 124
# https://pokemon.gameinfo.io/en/pokemon/125-electabuzz electabuzz 1 125
# https://pokemon.gameinfo.io/en/pokemon/126-magmar magmar 1 126
# https://pokemon.gameinfo.io/en/pokemon/127-pinsir pinsir 1 127
# https://pokemon.gameinfo.io/en/pokemon/128-tauros tauros 1 128
# https://pokemon.gameinfo.io/en/pokemon/129-magikarp magikarp 1 129
# https://pokemon.gameinfo.io/en/pokemon/130-gyarados gyarados 1 130
# https://pokemon.gameinfo.io/en/pokemon/131-lapras lapras 1 131
# https://pokemon.gameinfo.io/en/pokemon/132-ditto ditto 1 132
# https://pokemon.gameinfo.io/en/pokemon/133-eevee eevee 1 133
# https://pokemon.gameinfo.io/en/pokemon/134-vaporeon vaporeon 1 134
# https://pokemon.gameinfo.io/en/pokemon/135-jolteon jolteon 1 135
# https://pokemon.gameinfo.io/en/pokemon/136-flareon flareon 1 136
# https://pokemon.gameinfo.io/en/pokemon/137-porygon porygon 1 137
# https://pokemon.gameinfo.io/en/pokemon/138-omanyte omanyte 1 138
# https://pokemon.gameinfo.io/en/pokemon/139-omastar omastar 1 139
# https://pokemon.gameinfo.io/en/pokemon/140-kabuto kabuto 1 140
# https://pokemon.gameinfo.io/en/pokemon/141-kabutops kabutops 1 141
# https://pokemon.gameinfo.io/en/pokemon/142-aerodactyl aerodactyl 1 142
# https://pokemon.gameinfo.io/en/pokemon/143-snorlax snorlax 1 143
# https://pokemon.gameinfo.io/en/pokemon/144-articuno articuno 1 144
# https://pokemon.gameinfo.io/en/pokemon/145-zapdos zapdos 1 145
# https://pokemon.gameinfo.io/en/pokemon/146-moltres moltres 1 146
# https://pokemon.gameinfo.io/en/pokemon/147-dratini dratini 1 147
# https://pokemon.gameinfo.io/en/pokemon/148-dragonair dragonair 1 148
# https://pokemon.gameinfo.io/en/pokemon/149-dragonite dragonite 1 149
# https://pokemon.gameinfo.io/en/pokemon/150-mewtwo mewtwo 1 150
# https://pokemon.gameinfo.io/en/pokemon/151-mew mew 1 151
# https://pokemon.gameinfo.io/en/pokemon/172-pichu pichu 2 172
# https://pokemon.gameinfo.io/en/pokemon/173-cleffa cleffa 2 173
# https://pokemon.gameinfo.io/en/pokemon/174-igglybuff igglybuff 2 174
# https://pokemon.gameinfo.io/en/pokemon/169-crobat crobat 2 169
# https://pokemon.gameinfo.io/en/pokemon/182-bellossom bellossom 2 182
# https://pokemon.gameinfo.io/en/pokemon/186-politoed politoed 2 186
# https://pokemon.gameinfo.io/en/pokemon/199-slowking slowking 2 199
# https://pokemon.gameinfo.io/en/pokemon/208-steelix steelix 2 208
# https://pokemon.gameinfo.io/en/pokemon/236-tyrogue tyrogue 2 236
# https://pokemon.gameinfo.io/en/pokemon/237-hitmontop hitmontop 2 237
# https://pokemon.gameinfo.io/en/pokemon/242-blissey blissey 2 242
# https://pokemon.gameinfo.io/en/pokemon/230-kingdra kingdra 2 230
# https://pokemon.gameinfo.io/en/pokemon/212-scizor scizor 2 212
# https://pokemon.gameinfo.io/en/pokemon/238-smoochum smoochum 2 238
# https://pokemon.gameinfo.io/en/pokemon/239-elekid elekid 2 239
# https://pokemon.gameinfo.io/en/pokemon/240-magby magby 2 240
# https://pokemon.gameinfo.io/en/pokemon/196-espeon espeon 2 196
# https://pokemon.gameinfo.io/en/pokemon/197-umbreon umbreon 2 197
# https://pokemon.gameinfo.io/en/pokemon/233-porygon2 porygon2 2 233
# https://pokemon.gameinfo.io/en/pokemon/152-chikorita chikorita 2 152
# https://pokemon.gameinfo.io/en/pokemon/153-bayleef bayleef 2 153
# https://pokemon.gameinfo.io/en/pokemon/154-meganium meganium 2 154
# https://pokemon.gameinfo.io/en/pokemon/155-cyndaquil cyndaquil 2 155
# https://pokemon.gameinfo.io/en/pokemon/156-quilava quilava 2 156
# https://pokemon.gameinfo.io/en/pokemon/157-typhlosion typhlosion 2 157
# https://pokemon.gameinfo.io/en/pokemon/158-totodile totodile 2 158
# https://pokemon.gameinfo.io/en/pokemon/159-croconaw croconaw 2 159
# https://pokemon.gameinfo.io/en/pokemon/160-feraligatr feraligatr 2 160
# https://pokemon.gameinfo.io/en/pokemon/161-sentret sentret 2 161
# https://pokemon.gameinfo.io/en/pokemon/162-furret furret 2 162
# https://pokemon.gameinfo.io/en/pokemon/163-hoothoot hoothoot 2 163
# https://pokemon.gameinfo.io/en/pokemon/164-noctowl noctowl 2 164
# https://pokemon.gameinfo.io/en/pokemon/165-ledyba ledyba 2 165
# https://pokemon.gameinfo.io/en/pokemon/166-ledian ledian 2 166
# https://pokemon.gameinfo.io/en/pokemon/167-spinarak spinarak 2 167
# https://pokemon.gameinfo.io/en/pokemon/168-ariados ariados 2 168
# https://pokemon.gameinfo.io/en/pokemon/170-chinchou chinchou 2 170
# https://pokemon.gameinfo.io/en/pokemon/171-lanturn lanturn 2 171
# https://pokemon.gameinfo.io/en/pokemon/175-togepi togepi 2 175
# https://pokemon.gameinfo.io/en/pokemon/176-togetic togetic 2 176
# https://pokemon.gameinfo.io/en/pokemon/177-natu natu 2 177
# https://pokemon.gameinfo.io/en/pokemon/178-xatu xatu 2 178
# https://pokemon.gameinfo.io/en/pokemon/179-mareep mareep 2 179
# https://pokemon.gameinfo.io/en/pokemon/180-flaaffy flaaffy 2 180
# https://pokemon.gameinfo.io/en/pokemon/181-ampharos ampharos 2 181
# https://pokemon.gameinfo.io/en/pokemon/183-marill marill 2 183
# https://pokemon.gameinfo.io/en/pokemon/184-azumarill azumarill 2 184
# https://pokemon.gameinfo.io/en/pokemon/185-sudowoodo sudowoodo 2 185
# https://pokemon.gameinfo.io/en/pokemon/187-hoppip hoppip 2 187
# https://pokemon.gameinfo.io/en/pokemon/188-skiploom skiploom 2 188
# https://pokemon.gameinfo.io/en/pokemon/189-jumpluff jumpluff 2 189
# https://pokemon.gameinfo.io/en/pokemon/190-aipom aipom 2 190
# https://pokemon.gameinfo.io/en/pokemon/191-sunkern sunkern 2 191
# https://pokemon.gameinfo.io/en/pokemon/192-sunflora sunflora 2 192
# https://pokemon.gameinfo.io/en/pokemon/193-yanma yanma 2 193
# https://pokemon.gameinfo.io/en/pokemon/194-wooper wooper 2 194
# https://pokemon.gameinfo.io/en/pokemon/195-quagsire quagsire 2 195
# https://pokemon.gameinfo.io/en/pokemon/198-murkrow murkrow 2 198
# https://pokemon.gameinfo.io/en/pokemon/200-misdreavus misdreavus 2 200
# https://pokemon.gameinfo.io/en/pokemon/201-unown unown 2 201
# https://pokemon.gameinfo.io/en/pokemon/202-wobbuffet wobbuffet 2 202
# https://pokemon.gameinfo.io/en/pokemon/203-girafarig girafarig 2 203
# https://pokemon.gameinfo.io/en/pokemon/204-pineco pineco 2 204
# https://pokemon.gameinfo.io/en/pokemon/205-forretress forretress 2 205
# https://pokemon.gameinfo.io/en/pokemon/206-dunsparce dunsparce 2 206
# https://pokemon.gameinfo.io/en/pokemon/207-gligar gligar 2 207
# https://pokemon.gameinfo.io/en/pokemon/209-snubbull snubbull 2 209
# https://pokemon.gameinfo.io/en/pokemon/210-granbull granbull 2 210
# https://pokemon.gameinfo.io/en/pokemon/211-qwilfish qwilfish 2 211
# https://pokemon.gameinfo.io/en/pokemon/213-shuckle shuckle 2 213
# https://pokemon.gameinfo.io/en/pokemon/214-heracross heracross 2 214
# https://pokemon.gameinfo.io/en/pokemon/215-sneasel sneasel 2 215
# https://pokemon.gameinfo.io/en/pokemon/216-teddiursa teddiursa 2 216
# https://pokemon.gameinfo.io/en/pokemon/217-ursaring ursaring 2 217
# https://pokemon.gameinfo.io/en/pokemon/218-slugma slugma 2 218
# https://pokemon.gameinfo.io/en/pokemon/219-magcargo magcargo 2 219
# https://pokemon.gameinfo.io/en/pokemon/220-swinub swinub 2 220
# https://pokemon.gameinfo.io/en/pokemon/221-piloswine piloswine 2 221
# https://pokemon.gameinfo.io/en/pokemon/222-corsola corsola 2 222
# https://pokemon.gameinfo.io/en/pokemon/223-remoraid remoraid 2 223
# https://pokemon.gameinfo.io/en/pokemon/224-octillery octillery 2 224
# https://pokemon.gameinfo.io/en/pokemon/225-delibird delibird 2 225
# https://pokemon.gameinfo.io/en/pokemon/226-mantine mantine 2 226
# https://pokemon.gameinfo.io/en/pokemon/227-skarmory skarmory 2 227
# https://pokemon.gameinfo.io/en/pokemon/228-houndour houndour 2 228
# https://pokemon.gameinfo.io/en/pokemon/229-houndoom houndoom 2 229
# https://pokemon.gameinfo.io/en/pokemon/231-phanpy phanpy 2 231
# https://pokemon.gameinfo.io/en/pokemon/232-donphan donphan 2 232
# https://pokemon.gameinfo.io/en/pokemon/234-stantler stantler 2 234
# https://pokemon.gameinfo.io/en/pokemon/235-smeargle smeargle 2 235
# https://pokemon.gameinfo.io/en/pokemon/241-miltank miltank 2 241
# https://pokemon.gameinfo.io/en/pokemon/243-raikou raikou 2 243
# https://pokemon.gameinfo.io/en/pokemon/244-entei entei 2 244
# https://pokemon.gameinfo.io/en/pokemon/245-suicune suicune 2 245
# https://pokemon.gameinfo.io/en/pokemon/246-larvitar larvitar 2 246
# https://pokemon.gameinfo.io/en/pokemon/247-pupitar pupitar 2 247
# https://pokemon.gameinfo.io/en/pokemon/248-tyranitar tyranitar 2 248
# https://pokemon.gameinfo.io/en/pokemon/249-lugia lugia 2 249
# https://pokemon.gameinfo.io/en/pokemon/250-ho-oh ho-oh 2 250
# https://pokemon.gameinfo.io/en/pokemon/251-celebi celebi 2 251
# https://pokemon.gameinfo.io/en/pokemon/298-azurill azurill 3 298
# https://pokemon.gameinfo.io/en/pokemon/360-wynaut wynaut 3 360
# https://pokemon.gameinfo.io/en/pokemon/252-treecko treecko 3 252
# https://pokemon.gameinfo.io/en/pokemon/253-grovyle grovyle 3 253
# https://pokemon.gameinfo.io/en/pokemon/254-sceptile sceptile 3 254
# https://pokemon.gameinfo.io/en/pokemon/255-torchic torchic 3 255
# https://pokemon.gameinfo.io/en/pokemon/256-combusken combusken 3 256
# https://pokemon.gameinfo.io/en/pokemon/257-blaziken blaziken 3 257
# https://pokemon.gameinfo.io/en/pokemon/258-mudkip mudkip 3 258
# https://pokemon.gameinfo.io/en/pokemon/259-marshtomp marshtomp 3 259
# https://pokemon.gameinfo.io/en/pokemon/260-swampert swampert 3 260
# https://pokemon.gameinfo.io/en/pokemon/261-poochyena poochyena 3 261
# https://pokemon.gameinfo.io/en/pokemon/262-mightyena mightyena 3 262
# https://pokemon.gameinfo.io/en/pokemon/263-zigzagoon zigzagoon 3 263
# https://pokemon.gameinfo.io/en/pokemon/264-linoone linoone 3 264
# https://pokemon.gameinfo.io/en/pokemon/265-wurmple wurmple 3 265
# https://pokemon.gameinfo.io/en/pokemon/266-silcoon silcoon 3 266
# https://pokemon.gameinfo.io/en/pokemon/268-cascoon cascoon 3 268
# https://pokemon.gameinfo.io/en/pokemon/267-beautifly beautifly 3 267
# https://pokemon.gameinfo.io/en/pokemon/269-dustox dustox 3 269
# https://pokemon.gameinfo.io/en/pokemon/270-lotad lotad 3 270
# https://pokemon.gameinfo.io/en/pokemon/271-lombre lombre 3 271
# https://pokemon.gameinfo.io/en/pokemon/272-ludicolo ludicolo 3 272
# https://pokemon.gameinfo.io/en/pokemon/273-seedot seedot 3 273
# https://pokemon.gameinfo.io/en/pokemon/274-nuzleaf nuzleaf 3 274
# https://pokemon.gameinfo.io/en/pokemon/275-shiftry shiftry 3 275
# https://pokemon.gameinfo.io/en/pokemon/276-taillow taillow 3 276
# https://pokemon.gameinfo.io/en/pokemon/277-swellow swellow 3 277
# https://pokemon.gameinfo.io/en/pokemon/278-wingull wingull 3 278
# https://pokemon.gameinfo.io/en/pokemon/279-pelipper pelipper 3 279
# https://pokemon.gameinfo.io/en/pokemon/280-ralts ralts 3 280
# https://pokemon.gameinfo.io/en/pokemon/281-kirlia kirlia 3 281
# https://pokemon.gameinfo.io/en/pokemon/282-gardevoir gardevoir 3 282
# https://pokemon.gameinfo.io/en/pokemon/283-surskit surskit 3 283
# https://pokemon.gameinfo.io/en/pokemon/284-masquerain masquerain 3 284
# https://pokemon.gameinfo.io/en/pokemon/285-shroomish shroomish 3 285
# https://pokemon.gameinfo.io/en/pokemon/286-breloom breloom 3 286
# https://pokemon.gameinfo.io/en/pokemon/287-slakoth slakoth 3 287
# https://pokemon.gameinfo.io/en/pokemon/288-vigoroth vigoroth 3 288
# https://pokemon.gameinfo.io/en/pokemon/289-slaking slaking 3 289
# https://pokemon.gameinfo.io/en/pokemon/290-nincada nincada 3 290
# https://pokemon.gameinfo.io/en/pokemon/291-ninjask ninjask 3 291
# https://pokemon.gameinfo.io/en/pokemon/292-shedinja shedinja 3 292
# https://pokemon.gameinfo.io/en/pokemon/293-whismur whismur 3 293
# https://pokemon.gameinfo.io/en/pokemon/294-loudred loudred 3 294
# https://pokemon.gameinfo.io/en/pokemon/295-exploud exploud 3 295
# https://pokemon.gameinfo.io/en/pokemon/296-makuhita makuhita 3 296
# https://pokemon.gameinfo.io/en/pokemon/297-hariyama hariyama 3 297
# https://pokemon.gameinfo.io/en/pokemon/299-nosepass nosepass 3 299
# https://pokemon.gameinfo.io/en/pokemon/300-skitty skitty 3 300
# https://pokemon.gameinfo.io/en/pokemon/301-delcatty delcatty 3 301
# https://pokemon.gameinfo.io/en/pokemon/302-sableye sableye 3 302
# https://pokemon.gameinfo.io/en/pokemon/303-mawile mawile 3 303
# https://pokemon.gameinfo.io/en/pokemon/304-aron aron 3 304
# https://pokemon.gameinfo.io/en/pokemon/305-lairon lairon 3 305
# https://pokemon.gameinfo.io/en/pokemon/306-aggron aggron 3 306
# https://pokemon.gameinfo.io/en/pokemon/307-meditite meditite 3 307
# https://pokemon.gameinfo.io/en/pokemon/308-medicham medicham 3 308
# https://pokemon.gameinfo.io/en/pokemon/309-electrike electrike 3 309
# https://pokemon.gameinfo.io/en/pokemon/310-manectric manectric 3 310
# https://pokemon.gameinfo.io/en/pokemon/311-plusle plusle 3 311
# https://pokemon.gameinfo.io/en/pokemon/312-minun minun 3 312
# https://pokemon.gameinfo.io/en/pokemon/313-volbeat volbeat 3 313
# https://pokemon.gameinfo.io/en/pokemon/314-illumise illumise 3 314
# https://pokemon.gameinfo.io/en/pokemon/315-roselia roselia 3 315
# https://pokemon.gameinfo.io/en/pokemon/316-gulpin gulpin 3 316
# https://pokemon.gameinfo.io/en/pokemon/317-swalot swalot 3 317
# https://pokemon.gameinfo.io/en/pokemon/318-carvanha carvanha 3 318
# https://pokemon.gameinfo.io/en/pokemon/319-sharpedo sharpedo 3 319
# https://pokemon.gameinfo.io/en/pokemon/320-wailmer wailmer 3 320
# https://pokemon.gameinfo.io/en/pokemon/321-wailord wailord 3 321
# https://pokemon.gameinfo.io/en/pokemon/322-numel numel 3 322
# https://pokemon.gameinfo.io/en/pokemon/323-camerupt camerupt 3 323
# https://pokemon.gameinfo.io/en/pokemon/324-torkoal torkoal 3 324
# https://pokemon.gameinfo.io/en/pokemon/325-spoink spoink 3 325
# https://pokemon.gameinfo.io/en/pokemon/326-grumpig grumpig 3 326
# https://pokemon.gameinfo.io/en/pokemon/327-spinda spinda 3 327
# https://pokemon.gameinfo.io/en/pokemon/328-trapinch trapinch 3 328
# https://pokemon.gameinfo.io/en/pokemon/329-vibrava vibrava 3 329
# https://pokemon.gameinfo.io/en/pokemon/330-flygon flygon 3 330
# https://pokemon.gameinfo.io/en/pokemon/331-cacnea cacnea 3 331
# https://pokemon.gameinfo.io/en/pokemon/332-cacturne cacturne 3 332
# https://pokemon.gameinfo.io/en/pokemon/333-swablu swablu 3 333
# https://pokemon.gameinfo.io/en/pokemon/334-altaria altaria 3 334
# https://pokemon.gameinfo.io/en/pokemon/335-zangoose zangoose 3 335
# https://pokemon.gameinfo.io/en/pokemon/336-seviper seviper 3 336
# https://pokemon.gameinfo.io/en/pokemon/337-lunatone lunatone 3 337
# https://pokemon.gameinfo.io/en/pokemon/338-solrock solrock 3 338
# https://pokemon.gameinfo.io/en/pokemon/339-barboach barboach 3 339
# https://pokemon.gameinfo.io/en/pokemon/340-whiscash whiscash 3 340
# https://pokemon.gameinfo.io/en/pokemon/341-corphish corphish 3 341
# https://pokemon.gameinfo.io/en/pokemon/342-crawdaunt crawdaunt 3 342
# https://pokemon.gameinfo.io/en/pokemon/343-baltoy baltoy 3 343
# https://pokemon.gameinfo.io/en/pokemon/344-claydol claydol 3 344
# https://pokemon.gameinfo.io/en/pokemon/345-lileep lileep 3 345
# https://pokemon.gameinfo.io/en/pokemon/346-cradily cradily 3 346
# https://pokemon.gameinfo.io/en/pokemon/347-anorith anorith 3 347
# https://pokemon.gameinfo.io/en/pokemon/348-armaldo armaldo 3 348
# https://pokemon.gameinfo.io/en/pokemon/349-feebas feebas 3 349
# https://pokemon.gameinfo.io/en/pokemon/350-milotic milotic 3 350
# https://pokemon.gameinfo.io/en/pokemon/351-castform castform 3 351
# https://pokemon.gameinfo.io/en/pokemon/352-kecleon kecleon 3 352
# https://pokemon.gameinfo.io/en/pokemon/353-shuppet shuppet 3 353
# https://pokemon.gameinfo.io/en/pokemon/354-banette banette 3 354
# https://pokemon.gameinfo.io/en/pokemon/355-duskull duskull 3 355
# https://pokemon.gameinfo.io/en/pokemon/356-dusclops dusclops 3 356
# https://pokemon.gameinfo.io/en/pokemon/357-tropius tropius 3 357
# https://pokemon.gameinfo.io/en/pokemon/358-chimecho chimecho 3 358
# https://pokemon.gameinfo.io/en/pokemon/359-absol absol 3 359
# https://pokemon.gameinfo.io/en/pokemon/361-snorunt snorunt 3 361
# https://pokemon.gameinfo.io/en/pokemon/362-glalie glalie 3 362
# https://pokemon.gameinfo.io/en/pokemon/363-spheal spheal 3 363
# https://pokemon.gameinfo.io/en/pokemon/364-sealeo sealeo 3 364
# https://pokemon.gameinfo.io/en/pokemon/365-walrein walrein 3 365
# https://pokemon.gameinfo.io/en/pokemon/366-clamperl clamperl 3 366
# https://pokemon.gameinfo.io/en/pokemon/367-huntail huntail 3 367
# https://pokemon.gameinfo.io/en/pokemon/368-gorebyss gorebyss 3 368
# https://pokemon.gameinfo.io/en/pokemon/369-relicanth relicanth 3 369
# https://pokemon.gameinfo.io/en/pokemon/370-luvdisc luvdisc 3 370
# https://pokemon.gameinfo.io/en/pokemon/371-bagon bagon 3 371
# https://pokemon.gameinfo.io/en/pokemon/372-shelgon shelgon 3 372
# https://pokemon.gameinfo.io/en/pokemon/373-salamence salamence 3 373
# https://pokemon.gameinfo.io/en/pokemon/374-beldum beldum 3 374
# https://pokemon.gameinfo.io/en/pokemon/375-metang metang 3 375
# https://pokemon.gameinfo.io/en/pokemon/376-metagross metagross 3 376
# https://pokemon.gameinfo.io/en/pokemon/377-regirock regirock 3 377
# https://pokemon.gameinfo.io/en/pokemon/378-regice regice 3 378
# https://pokemon.gameinfo.io/en/pokemon/379-registeel registeel 3 379
# https://pokemon.gameinfo.io/en/pokemon/380-latias latias 3 380
# https://pokemon.gameinfo.io/en/pokemon/381-latios latios 3 381
# https://pokemon.gameinfo.io/en/pokemon/382-kyogre kyogre 3 382
# https://pokemon.gameinfo.io/en/pokemon/383-groudon groudon 3 383
# https://pokemon.gameinfo.io/en/pokemon/384-rayquaza rayquaza 3 384
# https://pokemon.gameinfo.io/en/pokemon/385-jirachi jirachi 3 385
# https://pokemon.gameinfo.io/en/pokemon/386-deoxys deoxys 3 386
# https://pokemon.gameinfo.io/en/pokemon/462-magnezone magnezone 4 462
# https://pokemon.gameinfo.io/en/pokemon/463-lickilicky lickilicky 4 463
# https://pokemon.gameinfo.io/en/pokemon/464-rhyperior rhyperior 4 464
# https://pokemon.gameinfo.io/en/pokemon/440-happiny happiny 4 440
# https://pokemon.gameinfo.io/en/pokemon/465-tangrowth tangrowth 4 465
# https://pokemon.gameinfo.io/en/pokemon/439-mime-jr mime jr. 4 439
# https://pokemon.gameinfo.io/en/pokemon/466-electivire electivire 4 466
# https://pokemon.gameinfo.io/en/pokemon/467-magmortar magmortar 4 467
# https://pokemon.gameinfo.io/en/pokemon/470-leafeon leafeon 4 470
# https://pokemon.gameinfo.io/en/pokemon/471-glaceon glaceon 4 471
# https://pokemon.gameinfo.io/en/pokemon/474-porygon-z porygon-z 4 474
# https://pokemon.gameinfo.io/en/pokemon/446-munchlax munchlax 4 446
# https://pokemon.gameinfo.io/en/pokemon/468-togekiss togekiss 4 468
# https://pokemon.gameinfo.io/en/pokemon/438-bonsly bonsly 4 438
# https://pokemon.gameinfo.io/en/pokemon/424-ambipom ambipom 4 424
# https://pokemon.gameinfo.io/en/pokemon/469-yanmega yanmega 4 469
# https://pokemon.gameinfo.io/en/pokemon/430-honchkrow honchkrow 4 430
# https://pokemon.gameinfo.io/en/pokemon/429-mismagius mismagius 4 429
# https://pokemon.gameinfo.io/en/pokemon/472-gliscor gliscor 4 472
# https://pokemon.gameinfo.io/en/pokemon/461-weavile weavile 4 461
# https://pokemon.gameinfo.io/en/pokemon/473-mamoswine mamoswine 4 473
# https://pokemon.gameinfo.io/en/pokemon/458-mantyke mantyke 4 458
# https://pokemon.gameinfo.io/en/pokemon/475-gallade gallade 4 475
# https://pokemon.gameinfo.io/en/pokemon/476-probopass probopass 4 476
# https://pokemon.gameinfo.io/en/pokemon/406-budew budew 4 406
# https://pokemon.gameinfo.io/en/pokemon/407-roserade roserade 4 407
# https://pokemon.gameinfo.io/en/pokemon/477-dusknoir dusknoir 4 477
# https://pokemon.gameinfo.io/en/pokemon/433-chingling chingling 4 433
# https://pokemon.gameinfo.io/en/pokemon/478-froslass froslass 4 478
# https://pokemon.gameinfo.io/en/pokemon/387-turtwig turtwig 4 387
# https://pokemon.gameinfo.io/en/pokemon/388-grotle grotle 4 388
# https://pokemon.gameinfo.io/en/pokemon/389-torterra torterra 4 389
# https://pokemon.gameinfo.io/en/pokemon/390-chimchar chimchar 4 390
# https://pokemon.gameinfo.io/en/pokemon/391-monferno monferno 4 391
# https://pokemon.gameinfo.io/en/pokemon/392-infernape infernape 4 392
# https://pokemon.gameinfo.io/en/pokemon/393-piplup piplup 4 393
# https://pokemon.gameinfo.io/en/pokemon/394-prinplup prinplup 4 394
# https://pokemon.gameinfo.io/en/pokemon/395-empoleon empoleon 4 395
# https://pokemon.gameinfo.io/en/pokemon/396-starly starly 4 396
# https://pokemon.gameinfo.io/en/pokemon/397-staravia staravia 4 397
# https://pokemon.gameinfo.io/en/pokemon/398-staraptor staraptor 4 398
# https://pokemon.gameinfo.io/en/pokemon/399-bidoof bidoof 4 399
# https://pokemon.gameinfo.io/en/pokemon/400-bibarel bibarel 4 400
# https://pokemon.gameinfo.io/en/pokemon/401-kricketot kricketot 4 401
# https://pokemon.gameinfo.io/en/pokemon/402-kricketune kricketune 4 402
# https://pokemon.gameinfo.io/en/pokemon/403-shinx shinx 4 403
# https://pokemon.gameinfo.io/en/pokemon/404-luxio luxio 4 404
# https://pokemon.gameinfo.io/en/pokemon/405-luxray luxray 4 405
# https://pokemon.gameinfo.io/en/pokemon/408-cranidos cranidos 4 408
# https://pokemon.gameinfo.io/en/pokemon/409-rampardos rampardos 4 409
# https://pokemon.gameinfo.io/en/pokemon/410-shieldon shieldon 4 410
# https://pokemon.gameinfo.io/en/pokemon/411-bastiodon bastiodon 4 411
# https://pokemon.gameinfo.io/en/pokemon/412-burmy burmy 4 412
# https://pokemon.gameinfo.io/en/pokemon/413-wormadam wormadam 4 413
# https://pokemon.gameinfo.io/en/pokemon/412-burmy burmy 4 412
# https://pokemon.gameinfo.io/en/pokemon/413-wormadam wormadam 4 413
# https://pokemon.gameinfo.io/en/pokemon/415-combee combee 4 415
# https://pokemon.gameinfo.io/en/pokemon/416-vespiquen vespiquen 4 416
# https://pokemon.gameinfo.io/en/pokemon/417-pachirisu pachirisu 4 417
# https://pokemon.gameinfo.io/en/pokemon/418-buizel buizel 4 418
# https://pokemon.gameinfo.io/en/pokemon/419-floatzel floatzel 4 419
# https://pokemon.gameinfo.io/en/pokemon/420-cherubi cherubi 4 420
# https://pokemon.gameinfo.io/en/pokemon/421-cherrim cherrim 4 421
# https://pokemon.gameinfo.io/en/pokemon/422-shellos shellos 4 422
# https://pokemon.gameinfo.io/en/pokemon/423-gastrodon gastrodon 4 423
# https://pokemon.gameinfo.io/en/pokemon/425-drifloon drifloon 4 425
# https://pokemon.gameinfo.io/en/pokemon/426-drifblim drifblim 4 426
# https://pokemon.gameinfo.io/en/pokemon/427-buneary buneary 4 427
# https://pokemon.gameinfo.io/en/pokemon/428-lopunny lopunny 4 428
# https://pokemon.gameinfo.io/en/pokemon/431-glameow glameow 4 431
# https://pokemon.gameinfo.io/en/pokemon/432-purugly purugly 4 432
# https://pokemon.gameinfo.io/en/pokemon/434-stunky stunky 4 434
# https://pokemon.gameinfo.io/en/pokemon/435-skuntank skuntank 4 435
# https://pokemon.gameinfo.io/en/pokemon/436-bronzor bronzor 4 436
# https://pokemon.gameinfo.io/en/pokemon/437-bronzong bronzong 4 437
# https://pokemon.gameinfo.io/en/pokemon/441-chatot chatot 4 441
# https://pokemon.gameinfo.io/en/pokemon/442-spiritomb spiritomb 4 442
# https://pokemon.gameinfo.io/en/pokemon/443-gible gible 4 443
# https://pokemon.gameinfo.io/en/pokemon/444-gabite gabite 4 444
# https://pokemon.gameinfo.io/en/pokemon/445-garchomp garchomp 4 445
# https://pokemon.gameinfo.io/en/pokemon/447-riolu riolu 4 447
# https://pokemon.gameinfo.io/en/pokemon/448-lucario lucario 4 448
# https://pokemon.gameinfo.io/en/pokemon/449-hippopotas hippopotas 4 449
# https://pokemon.gameinfo.io/en/pokemon/450-hippowdon hippowdon 4 450
# https://pokemon.gameinfo.io/en/pokemon/451-skorupi skorupi 4 451
# https://pokemon.gameinfo.io/en/pokemon/452-drapion drapion 4 452
# https://pokemon.gameinfo.io/en/pokemon/453-croagunk croagunk 4 453
# https://pokemon.gameinfo.io/en/pokemon/454-toxicroak toxicroak 4 454
# https://pokemon.gameinfo.io/en/pokemon/455-carnivine carnivine 4 455
# https://pokemon.gameinfo.io/en/pokemon/456-finneon finneon 4 456
# https://pokemon.gameinfo.io/en/pokemon/457-lumineon lumineon 4 457
# https://pokemon.gameinfo.io/en/pokemon/459-snover snover 4 459
# https://pokemon.gameinfo.io/en/pokemon/460-abomasnow abomasnow 4 460
# https://pokemon.gameinfo.io/en/pokemon/479-rotom rotom 4 479
# https://pokemon.gameinfo.io/en/pokemon/480-uxie uxie 4 480
# https://pokemon.gameinfo.io/en/pokemon/481-mesprit mesprit 4 481
# https://pokemon.gameinfo.io/en/pokemon/482-azelf azelf 4 482
# https://pokemon.gameinfo.io/en/pokemon/483-dialga dialga 4 483
# https://pokemon.gameinfo.io/en/pokemon/484-palkia palkia 4 484
# https://pokemon.gameinfo.io/en/pokemon/485-heatran heatran 4 485
# https://pokemon.gameinfo.io/en/pokemon/486-regigigas regigigas 4 486
# https://pokemon.gameinfo.io/en/pokemon/487-giratina giratina 4 487
# https://pokemon.gameinfo.io/en/pokemon/488-cresselia cresselia 4 488
# https://pokemon.gameinfo.io/en/pokemon/489-phione phione 4 489
# https://pokemon.gameinfo.io/en/pokemon/490-manaphy manaphy 4 490
# https://pokemon.gameinfo.io/en/pokemon/491-darkrai darkrai 4 491
# https://pokemon.gameinfo.io/en/pokemon/492-shaymin shaymin 4 492
# https://pokemon.gameinfo.io/en/pokemon/493-arceus arceus 4 493
# https://pokemon.gameinfo.io/en/pokemon/494-victini victini 5 494
# https://pokemon.gameinfo.io/en/pokemon/495-snivy snivy 5 495
# https://pokemon.gameinfo.io/en/pokemon/496-servine servine 5 496
# https://pokemon.gameinfo.io/en/pokemon/497-serperior serperior 5 497
# https://pokemon.gameinfo.io/en/pokemon/498-tepig tepig 5 498
# https://pokemon.gameinfo.io/en/pokemon/499-pignite pignite 5 499
# https://pokemon.gameinfo.io/en/pokemon/500-emboar emboar 5 500
# https://pokemon.gameinfo.io/en/pokemon/501-oshawott oshawott 5 501
# https://pokemon.gameinfo.io/en/pokemon/502-dewott dewott 5 502
# https://pokemon.gameinfo.io/en/pokemon/503-samurott samurott 5 503
# https://pokemon.gameinfo.io/en/pokemon/504-patrat patrat 5 504
# https://pokemon.gameinfo.io/en/pokemon/505-watchog watchog 5 505
# https://pokemon.gameinfo.io/en/pokemon/506-lillipup lillipup 5 506
# https://pokemon.gameinfo.io/en/pokemon/507-herdier herdier 5 507
# https://pokemon.gameinfo.io/en/pokemon/508-stoutland stoutland 5 508
# https://pokemon.gameinfo.io/en/pokemon/509-purrloin purrloin 5 509
# https://pokemon.gameinfo.io/en/pokemon/510-liepard liepard 5 510
# https://pokemon.gameinfo.io/en/pokemon/511-pansage pansage 5 511
# https://pokemon.gameinfo.io/en/pokemon/512-simisage simisage 5 512
# https://pokemon.gameinfo.io/en/pokemon/513-pansear pansear 5 513
# https://pokemon.gameinfo.io/en/pokemon/514-simisear simisear 5 514
# https://pokemon.gameinfo.io/en/pokemon/515-panpour panpour 5 515
# https://pokemon.gameinfo.io/en/pokemon/516-simipour simipour 5 516
# https://pokemon.gameinfo.io/en/pokemon/517-munna munna 5 517
# https://pokemon.gameinfo.io/en/pokemon/518-musharna musharna 5 518
# https://pokemon.gameinfo.io/en/pokemon/519-pidove pidove 5 519
# https://pokemon.gameinfo.io/en/pokemon/520-tranquill tranquill 5 520
# https://pokemon.gameinfo.io/en/pokemon/521-unfezant unfezant 5 521
# https://pokemon.gameinfo.io/en/pokemon/522-blitzle blitzle 5 522
# https://pokemon.gameinfo.io/en/pokemon/523-zebstrika zebstrika 5 523
# https://pokemon.gameinfo.io/en/pokemon/524-roggenrola roggenrola 5 524
# https://pokemon.gameinfo.io/en/pokemon/525-boldore boldore 5 525
# https://pokemon.gameinfo.io/en/pokemon/526-gigalith gigalith 5 526
# https://pokemon.gameinfo.io/en/pokemon/527-woobat woobat 5 527
# https://pokemon.gameinfo.io/en/pokemon/528-swoobat swoobat 5 528
# https://pokemon.gameinfo.io/en/pokemon/529-drilbur drilbur 5 529
# https://pokemon.gameinfo.io/en/pokemon/530-excadrill excadrill 5 530
# https://pokemon.gameinfo.io/en/pokemon/531-audino audino 5 531
# https://pokemon.gameinfo.io/en/pokemon/532-timburr timburr 5 532
# https://pokemon.gameinfo.io/en/pokemon/533-gurdurr gurdurr 5 533
# https://pokemon.gameinfo.io/en/pokemon/534-conkeldurr conkeldurr 5 534
# https://pokemon.gameinfo.io/en/pokemon/535-tympole tympole 5 535
# https://pokemon.gameinfo.io/en/pokemon/536-palpitoad palpitoad 5 536
# https://pokemon.gameinfo.io/en/pokemon/537-seismitoad seismitoad 5 537
# https://pokemon.gameinfo.io/en/pokemon/538-throh throh 5 538
# https://pokemon.gameinfo.io/en/pokemon/539-sawk sawk 5 539
# https://pokemon.gameinfo.io/en/pokemon/540-sewaddle sewaddle 5 540
# https://pokemon.gameinfo.io/en/pokemon/541-swadloon swadloon 5 541
# https://pokemon.gameinfo.io/en/pokemon/542-leavanny leavanny 5 542
# https://pokemon.gameinfo.io/en/pokemon/543-venipede venipede 5 543
# https://pokemon.gameinfo.io/en/pokemon/544-whirlipede whirlipede 5 544
# https://pokemon.gameinfo.io/en/pokemon/545-scolipede scolipede 5 545
# https://pokemon.gameinfo.io/en/pokemon/546-cottonee cottonee 5 546
# https://pokemon.gameinfo.io/en/pokemon/547-whimsicott whimsicott 5 547
# https://pokemon.gameinfo.io/en/pokemon/548-petilil petilil 5 548
# https://pokemon.gameinfo.io/en/pokemon/549-lilligant lilligant 5 549
# https://pokemon.gameinfo.io/en/pokemon/550-basculin basculin 5 550
# https://pokemon.gameinfo.io/en/pokemon/551-sandile sandile 5 551
# https://pokemon.gameinfo.io/en/pokemon/552-krokorok krokorok 5 552
# https://pokemon.gameinfo.io/en/pokemon/553-krookodile krookodile 5 553
# https://pokemon.gameinfo.io/en/pokemon/554-darumaka darumaka 5 554
# https://pokemon.gameinfo.io/en/pokemon/555-darmanitan darmanitan 5 555
# https://pokemon.gameinfo.io/en/pokemon/556-maractus maractus 5 556
# https://pokemon.gameinfo.io/en/pokemon/557-dwebble dwebble 5 557
# https://pokemon.gameinfo.io/en/pokemon/558-crustle crustle 5 558
# https://pokemon.gameinfo.io/en/pokemon/559-scraggy scraggy 5 559
# https://pokemon.gameinfo.io/en/pokemon/560-scrafty scrafty 5 560
# https://pokemon.gameinfo.io/en/pokemon/561-sigilyph sigilyph 5 561
# https://pokemon.gameinfo.io/en/pokemon/562-yamask yamask 5 562
# https://pokemon.gameinfo.io/en/pokemon/563-cofagrigus cofagrigus 5 563
# https://pokemon.gameinfo.io/en/pokemon/564-tirtouga tirtouga 5 564
# https://pokemon.gameinfo.io/en/pokemon/565-carracosta carracosta 5 565
# https://pokemon.gameinfo.io/en/pokemon/566-archen archen 5 566
# https://pokemon.gameinfo.io/en/pokemon/567-archeops archeops 5 567
# https://pokemon.gameinfo.io/en/pokemon/568-trubbish trubbish 5 568
# https://pokemon.gameinfo.io/en/pokemon/569-garbodor garbodor 5 569
# https://pokemon.gameinfo.io/en/pokemon/570-zorua zorua 5 570
# https://pokemon.gameinfo.io/en/pokemon/571-zoroark zoroark 5 571
# https://pokemon.gameinfo.io/en/pokemon/572-minccino minccino 5 572
# https://pokemon.gameinfo.io/en/pokemon/573-cinccino cinccino 5 573
# https://pokemon.gameinfo.io/en/pokemon/574-gothita gothita 5 574
# https://pokemon.gameinfo.io/en/pokemon/575-gothorita gothorita 5 575
# https://pokemon.gameinfo.io/en/pokemon/576-gothitelle gothitelle 5 576
# https://pokemon.gameinfo.io/en/pokemon/577-solosis solosis 5 577
# https://pokemon.gameinfo.io/en/pokemon/578-duosion duosion 5 578
# https://pokemon.gameinfo.io/en/pokemon/579-reuniclus reuniclus 5 579
# https://pokemon.gameinfo.io/en/pokemon/580-ducklett ducklett 5 580
# https://pokemon.gameinfo.io/en/pokemon/581-swanna swanna 5 581
# https://pokemon.gameinfo.io/en/pokemon/582-vanillite vanillite 5 582
# https://pokemon.gameinfo.io/en/pokemon/583-vanillish vanillish 5 583
# https://pokemon.gameinfo.io/en/pokemon/584-vanilluxe vanilluxe 5 584
# https://pokemon.gameinfo.io/en/pokemon/585-deerling deerling 5 585
# https://pokemon.gameinfo.io/en/pokemon/586-sawsbuck sawsbuck 5 586
# https://pokemon.gameinfo.io/en/pokemon/587-emolga emolga 5 587
# https://pokemon.gameinfo.io/en/pokemon/588-karrablast karrablast 5 588
# https://pokemon.gameinfo.io/en/pokemon/589-escavalier escavalier 5 589
# https://pokemon.gameinfo.io/en/pokemon/590-foongus foongus 5 590
# https://pokemon.gameinfo.io/en/pokemon/591-amoonguss amoonguss 5 591
# https://pokemon.gameinfo.io/en/pokemon/592-frillish frillish 5 592
# https://pokemon.gameinfo.io/en/pokemon/593-jellicent jellicent 5 593
# https://pokemon.gameinfo.io/en/pokemon/594-alomomola alomomola 5 594
# https://pokemon.gameinfo.io/en/pokemon/595-joltik joltik 5 595
# https://pokemon.gameinfo.io/en/pokemon/596-galvantula galvantula 5 596
# https://pokemon.gameinfo.io/en/pokemon/597-ferroseed ferroseed 5 597
# https://pokemon.gameinfo.io/en/pokemon/598-ferrothorn ferrothorn 5 598
# https://pokemon.gameinfo.io/en/pokemon/599-klink klink 5 599
# https://pokemon.gameinfo.io/en/pokemon/600-klang klang 5 600
# https://pokemon.gameinfo.io/en/pokemon/601-klinklang klinklang 5 601
# https://pokemon.gameinfo.io/en/pokemon/602-tynamo tynamo 5 602
# https://pokemon.gameinfo.io/en/pokemon/603-eelektrik eelektrik 5 603
# https://pokemon.gameinfo.io/en/pokemon/604-eelektross eelektross 5 604
# https://pokemon.gameinfo.io/en/pokemon/605-elgyem elgyem 5 605
# https://pokemon.gameinfo.io/en/pokemon/606-beheeyem beheeyem 5 606
# https://pokemon.gameinfo.io/en/pokemon/607-litwick litwick 5 607
# https://pokemon.gameinfo.io/en/pokemon/608-lampent lampent 5 608
# https://pokemon.gameinfo.io/en/pokemon/609-chandelure chandelure 5 609
# https://pokemon.gameinfo.io/en/pokemon/610-axew axew 5 610
# https://pokemon.gameinfo.io/en/pokemon/611-fraxure fraxure 5 611
# https://pokemon.gameinfo.io/en/pokemon/612-haxorus haxorus 5 612
# https://pokemon.gameinfo.io/en/pokemon/613-cubchoo cubchoo 5 613
# https://pokemon.gameinfo.io/en/pokemon/614-beartic beartic 5 614
# https://pokemon.gameinfo.io/en/pokemon/615-cryogonal cryogonal 5 615
# https://pokemon.gameinfo.io/en/pokemon/616-shelmet shelmet 5 616
# https://pokemon.gameinfo.io/en/pokemon/617-accelgor accelgor 5 617
# https://pokemon.gameinfo.io/en/pokemon/618-stunfisk stunfisk 5 618
# https://pokemon.gameinfo.io/en/pokemon/619-mienfoo mienfoo 5 619
# https://pokemon.gameinfo.io/en/pokemon/620-mienshao mienshao 5 620
# https://pokemon.gameinfo.io/en/pokemon/621-druddigon druddigon 5 621
# https://pokemon.gameinfo.io/en/pokemon/622-golett golett 5 622
# https://pokemon.gameinfo.io/en/pokemon/623-golurk golurk 5 623
# https://pokemon.gameinfo.io/en/pokemon/624-pawniard pawniard 5 624
# https://pokemon.gameinfo.io/en/pokemon/625-bisharp bisharp 5 625
# https://pokemon.gameinfo.io/en/pokemon/626-bouffalant bouffalant 5 626
# https://pokemon.gameinfo.io/en/pokemon/627-rufflet rufflet 5 627
# https://pokemon.gameinfo.io/en/pokemon/628-braviary braviary 5 628
# https://pokemon.gameinfo.io/en/pokemon/629-vullaby vullaby 5 629
# https://pokemon.gameinfo.io/en/pokemon/630-mandibuzz mandibuzz 5 630
# https://pokemon.gameinfo.io/en/pokemon/631-heatmor heatmor 5 631
# https://pokemon.gameinfo.io/en/pokemon/632-durant durant 5 632
# https://pokemon.gameinfo.io/en/pokemon/633-deino deino 5 633
# https://pokemon.gameinfo.io/en/pokemon/634-zweilous zweilous 5 634
# https://pokemon.gameinfo.io/en/pokemon/635-hydreigon hydreigon 5 635
# https://pokemon.gameinfo.io/en/pokemon/636-larvesta larvesta 5 636
# https://pokemon.gameinfo.io/en/pokemon/637-volcarona volcarona 5 637
# https://pokemon.gameinfo.io/en/pokemon/638-cobalion cobalion 5 638
# https://pokemon.gameinfo.io/en/pokemon/639-terrakion terrakion 5 639
# https://pokemon.gameinfo.io/en/pokemon/640-virizion virizion 5 640
# https://pokemon.gameinfo.io/en/pokemon/641-tornadus tornadus 5 641
# https://pokemon.gameinfo.io/en/pokemon/642-thundurus thundurus 5 642
# https://pokemon.gameinfo.io/en/pokemon/643-reshiram reshiram 5 643
# https://pokemon.gameinfo.io/en/pokemon/644-zekrom zekrom 5 644
# https://pokemon.gameinfo.io/en/pokemon/645-landorus landorus 5 645
# https://pokemon.gameinfo.io/en/pokemon/646-kyurem kyurem 5 646
# https://pokemon.gameinfo.io/en/pokemon/647-keldeo keldeo 5 647
# https://pokemon.gameinfo.io/en/pokemon/648-meloetta meloetta 5 648
# https://pokemon.gameinfo.io/en/pokemon/649-genesect genesect 5 649
# https://pokemon.gameinfo.io/en/pokemon/808-meltan meltan 7 808
# https://pokemon.gameinfo.io/en/pokemon/809-melmetal melmetal 7 809

# %%
assert len(pokemon_data) == len(hrefs)

# %%
pokemon_df = pd.DataFrame(pokemon_data)
pokemon_df.head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-7644a85f9cca> in <module>
# ----> 1 pokemon_df = pd.DataFrame(pokemon_data)
#       2 pokemon_df.head(3)
#
# NameError: name 'pd' is not defined

# %%
# check which fields contain missing values
pokemon_df.isnull().sum()

# %%
# check which pokemon have missing img urls
rows_with_missing_img = pokemon_df[pokemon_df['Image URL'].isnull()][['ID','Name','Image URL']]
rows_with_missing_img.head()

# %%
# get IDs for pokemon with missing img urls
missing_img_IDs = rows_with_missing_img['ID'].values

# %%
url = 'https://www.pokemon.com/us/pokedex/'

# %%
# obtain missing img urls from different source
def get_IMG_urls(driver, ID_list):
    img_urls = []
    
    for ID in ID_list:
        driver.get(url)
        search_bar = driver.find_element_by_id('searchInput')
        search_bar.clear()
        time.sleep(3)
        search_bar.send_keys(ID, Keys.RETURN)
        time.sleep(5)
        try:
            img_url = driver.find_element_by_css_selector('ul.results').find_element_by_tag_name('img').get_attribute('src')
            print(img_url)
            img_urls.append(img_url)
        except:
            img_urls.append(None)
    
    driver.close()
        
    return img_urls

# %%
assert len(img_urls) == len(missing_img_IDs)

# %%
pokemon_df.at[rows_with_missing_img.index,'Image URL'] = img_urls

# %%
pokemon_df.isnull().sum()

# %%
pokemon_df.head()

# %%
pokemon_df.info()

# %%
# save data scraped data to csv file
data_path = 'data/pokemon_data_full.csv'

pokemon_df.to_csv(data_path)

# %%
# check that it saved properly
df = pd.read_csv(data_path, header=0, index_col=0)
df.head()

# %%
df.info()
